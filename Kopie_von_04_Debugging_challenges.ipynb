# %% [markdown]
# <a href="https://colab.research.google.com/github/Cooljoe67/Python_learning_experience/blob/main/Kopie_von_04_Debugging_challenges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Debugging Exercises 🐞
# Welcome! In each exercise below, you'll find some buggy Python code. 🐛 Your mission is to fix the error and get the code running. We give hints to help you along the way! 😊

# %% [markdown]
# ---
# ## Exercise 1
# The code is trying to print a greeting, but there's a bug 🐛 in the `print` statement.

# %%
print "Hello, world!"
# Out:
#   File "/tmp/ipython-input-4007745712.py", line 1
#     print "Hello, world!"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %% [markdown]
# ---
# ## Exercise 2
# We have a variable `message`, but I can't print it. Uh oh!

# %%
message = "Hi there!"
print(mesage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2960613811.py in <cell line: 0>()
#       1 message = "Hi there!"
# ----> 2 print(mesage)
#
# NameError: name 'mesage' is not defined

# %% [markdown]
# ---
# ## Exercise 3
# Our `print` statement is having problems again. Can you find what's wrong here?

# %%
if True:
print("Oh no!")
# Out:
#   File "/tmp/ipython-input-1275040913.py", line 2
#     print("Oh no!")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# ---
# ## Exercise 4
# If only this would work!

# %%
if 5 > 3
    print("5 is greater than 3")
# Out:
#   File "/tmp/ipython-input-996193472.py", line 1
#     if 5 > 3
#             ^
# SyntaxError: expected ':'

# %% [markdown]
# ---
# ## Exercise 5
# Why won't this code print out my age?

# %%
age = 30
print("I am " + age + " years old")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-457265232.py in <cell line: 0>()
#       1 age = 30
# ----> 2 print("I am " + age + " years old")
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ---
# ## Exercise 6
# I'd like to print out the `cherry`, why won't the code let me?

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3211090024.py in <cell line: 0>()
#       1 fruits = ["apple", "banana", "cherry"]
# ----> 2 print(fruits[3])
#
# IndexError: list index out of range

# %% [markdown]
# ---
# ## Exercise 7
# Why can't `int()` turn `ten` into an integer? Can it convert stings to integers?

# %%
number = int("ten")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-47378145.py in <cell line: 0>()
# ----> 1 number = int("ten")
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# ---
# ## Exercise 8
# What's wrong with the loop?

# %%
for i in range(3)
    print(i)
# Out:
#   File "/tmp/ipython-input-859882524.py", line 1
#     for i in range(3)
#                      ^
# SyntaxError: expected ':'

# %% [markdown]
# ---
# ## Exercise 9
# A string isn't recognised? What's up?

# %%
print("Hello)
# Out:
#   File "/tmp/ipython-input-1371898898.py", line 1
#     print("Hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# ---
# ## Exercise 10
# Is it possible to multiply a string? If so, how?

# %%
sound = "ha"
print(sound * 2.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-88789409.py in <cell line: 0>()
#       1 sound = "ha"
# ----> 2 print(sound * 2.5)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# ---
# ## Exercise 11
# What's wrong with this loop?

# %%
for i in range(5.5):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-37181651.py in <cell line: 0>()
# ----> 1 for i in range(5.5):
#       2     print(i)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# ---
# ## Exercise 12
# Why can't the list be printed?

# %%
items = [1, 2, 3]
print(item)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2175550346.py in <cell line: 0>()
#       1 items = [1, 2, 3]
# ----> 2 print(item)
#
# NameError: name 'item' is not defined

# %% [markdown]
# ---
# ## Exercise 13
# Why won't this code print out the 5 letter of `hello`?

# %%
s = "hello"
print(s[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3031940871.py in <cell line: 0>()
#       1 s = "hello"
# ----> 2 print(s[5])
#
# IndexError: string index out of range

# %% [markdown]
# ---
# ## Exercise 14
# Why can't `4` be added to the list? Can you add `4` to the list in `print()`?

# %%
nums = [1, 2, 3]
nums.append(4)
print(nums)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ---
# ## Exercise 15
# Nothing plus 5 is surely 5. Is it possible to save this code?

# %%
def ifnone(var,default):
  if var is None:
    return default
  return var

value = None
print(ifnone(value,0) + 5)
# Out:
# 5
